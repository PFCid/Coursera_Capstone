# %% [markdown]
# # IBM Coursera Data Science -  Capstone Course
# In this jupyter notebook I will develop my capstone for the course Applied Data Science Capstone, inside of the IBM Data Science Certificate
#
# Thhe document will analyze the data in order to find the best neighborhood to move due to the a new job position

# %%
import numpy as np
import pandas as pd
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
